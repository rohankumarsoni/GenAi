# %%
from langchain_openai import ChatOpenAI 
from langchain_google_genai import ChatGoogleGenerativeAI
from dotenv import load_dotenv

load_dotenv()

model = ChatGoogleGenerativeAI(model='gemini-3.5-flash')
result = model.invoke("write a 5 line poem on cricket")

print(result.content[0]["text"])
# Out:
# The bowler runs beneath the golden sun,
# With hopes to see the wickets overrun.
# The batsman swings with all his might and grace,
# And sends the leather ball through empty space,
# To seal the victory when the chase is done.
