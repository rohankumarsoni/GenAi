# %%
from langchain_openai import OpenAIEmbeddings
from dotenv import load_dotenv

load_dotenv()

embedding = OpenAIEmbeddings(model='text-embedding-3-large', dimensions=32)
result = embedding.embed_query("Delhi is the capital of India")

print(str(result))
# Out:
# [-0.1622314453125, 0.276611328125, -0.0077056884765625, 0.448974609375, -0.005962371826171875, 0.118408203125, -0.027557373046875, 0.0667724609375, -0.09149169921875, 0.006549835205078125, -0.0204620361328125, 0.1490478515625, -0.0171966552734375, -0.1451416015625, -0.1876220703125, -0.2034912109375, -0.1817626953125, 0.1192626953125, 0.07440185546875, -0.283447265625, 0.0294036865234375, -0.0205535888671875, 0.07220458984375, -3.933906555175781e-05, -0.31982421875, 0.410400390625, 0.320556640625, -0.048065185546875, -0.10614013671875, 0.0043182373046875, 0.05426025390625, 0.131103515625]
